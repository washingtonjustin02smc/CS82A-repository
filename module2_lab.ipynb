# %% [markdown]
# # CS 82A — Module 2 Lab
#
# **Name:** Justin
#
# This notebook practices Python variables, loops, functions, dictionaries, pandas, CSV files, and Git/GitHub.

# %% [markdown]
# ## Step 1: Wages with f-strings

# %%
name = "Justin"
hourly_wage = 20.00
hours = 32

weekly_pay = hourly_wage * hours

print(f"{name} earns {weekly_pay} per week")
# Out:
# Justin earns 640.0 per week

# %% [markdown]
# ## Step 2: Count the warm days

# %%
temps = [61, 65, 72, 58, 70, 74, 68]

warm_days = 0

for temp in temps:
    if temp > 65:
        warm_days = warm_days + 1

print(warm_days)
# Out:
# 4

# %% [markdown]
# ## Step 3: Write a temperature converter

# %%
def to_celsius(f):
    return (f - 32) * 5/9

print(round(to_celsius(temps[0]), 1))
# Out:
# 16.1

# %% [markdown]
# ## Step 4: A movie dictionary

# %%
movie = {
    "title": "The Fast and the Furious",
    "year": 2001,
    "rating": 6.8
}

for key, value in movie.items():
    print(key, ":", value)
# Out:
# title : The Fast and the Furious
# year : 2001
# rating : 6.8

# %% [markdown]
# ## Step 5: Load and inspect chickwts.csv

# %%
import pandas as pd

df = pd.read_csv("chickwts.csv", index_col=0)

df.head()
# Out:
#    weight       feed
# 1     179  horsebean
# 2     160  horsebean
# 3     136  horsebean
# 4     227  horsebean
# 5     217  horsebean

# %%
df.shape
# Out:
# (71, 2)

# %%
df.describe()
# Out:
#            weight
# count   71.000000
# mean   261.309859
# std     78.073700
# min    108.000000
# 25%    204.500000
# 50%    258.000000
# 75%    323.500000
# max    423.000000

# %% [markdown]
# ## Step 6: Interpret `describe()`
#
# Write **2–3 sentences in your own words** explaining what the `describe()` output tells you about the chick weights. Mention the typical weight, the spread/variation, and anything surprising that you notice.
#
# **Your response:**
#
# [Write your own 2–3 sentence interpretation here.]

# %% [markdown]
# ## GitHub Repository
#
# Repository name: `cs82a-portfolio`
#
# README description:
#
# Hi, I'm Justin. This repository has my work for CS 82A. I am learning Python, data analysis, pandas, and Git/GitHub as part of the course.
#
# Module 2: Python foundations

# %% [markdown]
# ## Submission
#
# GitHub repository URL:
#
# [Paste your public GitHub repository URL here.]
