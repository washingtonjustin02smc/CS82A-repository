# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from scipy.stats import linregress

truck = pd.read_csv("truck.csv")
truck.head()
# Out:
# X            Y
# 12.39999962  11.19999981
# 14.30000019  12.5
# 14.5         12.69999981
# 14.89999962  13.10000038
# 16.10000038  14.10000038

# %%
r, p_value = pearsonr(truck["X"], truck["Y"])
print(f"Pearson r: {r:.5f}")
# Out:
# Pearson r: 0.99854

# %%
plt.scatter(truck["X"], truck["Y"])
plt.xlabel("List Price (thousands of dollars)")
plt.ylabel("Best Sale Price (thousands of dollars)")
plt.title("Truck List Price and Best Sale Price Have a Very Strong Linear Relationship")
plt.show()

# %%
slope, intercept, r_value, p_value, std_err = linregress(truck["X"], truck["Y"])
list_price = 20
predicted_price = slope * list_price + intercept

print(f"List price: ${list_price * 1000:,.0f}")
print(f"Predicted best price: ${predicted_price * 1000:,.0f}")
# Out:
# List price: $20,000
# Predicted best price: $17,457

# %% [markdown]
# I am confident in this prediction because the correlation is close to 1 that shows a very strong relationship between list price and sale price. This prediction might not be as accurate for trucks with prices outside of the dataset.

# %% [markdown]
# https://github.com/washingtonjustin02smc/CS82A-repository
